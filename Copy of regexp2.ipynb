# %% [markdown]
# # Регулярные выражения
#
# `или` в регулярных выражениях: напишите регулярку, которая находит всех котиков.

# %%
import re

# %%
expample = 'Я пришла на каток, а там был котик! Я люблю котиков, а этот был очень милый. Уруру, котеек!'

# %%
re.findall ("кот.+?к(?:w+)?", expample)
# Out:
# ['котик', 'котик', 'котеек']

# %% [markdown]
# интервалы: найдите все даты

# %%
example = '23.07.1995, 223.56.1212 qqq 45.14.2019 qwqwr 01.08.1992 31.12.2017 05.11.1987'

# %%
re.findall ("[3][0-1][.]|[0-2][0-9][.][0-1][1-9][.]\d{4}",example)
# Out:
# ['23.07.1995', '01.08.1992', '31.', '05.11.1987']

# %% [markdown]
# Нежадный поиск: выделите все последовательности, которые оканчиваются на 3

# %%
example = '1243 12kjn3'

# %%
re.findall("\w+?3", example)
# Out:
# ['1243', '12kjn3']

# %% [markdown]
# Токенизация:
